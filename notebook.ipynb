# %% [markdown]
# ![eiffel-tower](images/eiffel-tower.png)
#
# As a distinguished AI Developer, you've been selected by Peterman Reality Tours, an internationally acclaimed tourism company, to undertake an influential project. This project requires you to harness the potential of OpenAI's API, to create an AI-powered travel guide for the culturally rich city of Paris.
#
# Your creation will become a virtual Parisian expert, delivering valuable insights into the city's iconic landmarks and hidden treasures. The AI will respond intelligently to a set of common questions, providing a more engaging and immersive travel planning experience for the clientele of Peterman Reality Tours.
#
# The ultimate aspiration is a user-friendly, AI-driven travel guide that significantly enhances the exploration of Paris. Users will be able to pre-define their questions and receive well-informed answers from the AI, providing a seamless and intuitive travel planning process.

# %%
import os
from openai import OpenAI

# Define the model to use
model = "gpt-4o-mini"

# Define the client
client = OpenAI()

# Start coding here
conversation = [
    {"role": "system",
     "content": "You are a helpful travel guide that enhances users' exploration of Paris"}
]

user_qs = [
    "How far away is the Louvre from the Eiffel Tower (in miles) if you are driving?",
    "Where is the Arc de Triomphe?",
    "What are the must-see artworks at the Louvre Museum?"
]

# Store assistant responses for each user question
assistant_responses = []

# For each user question, append to conversation, get response, and append assistant's reply
for q in user_qs:
    user_dict = {"role": "user", "content": q}
    conversation.append(user_dict)
    response = client.chat.completions.create(
        model=model,
        messages=conversation,
        temperature=0.0,
        max_tokens=200
    )
    assistant_reply = response.choices[0].message.content
    assistant_dict = {"role": "assistant", "content": assistant_reply}
    conversation.append(assistant_dict)
    assistant_responses.append(assistant_reply)

# Display the Q&A pairs
for q, a in zip(user_qs, assistant_responses):
    display({"User": q, "Assistant": a})
# Out:
# {'User': 'How far away is the Louvre from the Eiffel Tower (in miles) if you are driving?',
#  'Assistant': 'The distance from the Louvre Museum to the Eiffel Tower is approximately 3 miles (about 5 kilometers) when driving. Depending on traffic conditions, the drive can take around 15 to 30 minutes. Enjoy your visit to both iconic landmarks!'}
# {'User': 'Where is the Arc de Triomphe?',
#  'Assistant': 'The Arc de Triomphe is located at the western end of the Champs-Élysées in the 8th arrondissement of Paris, France. It stands at the Place Charles de Gaulle, where several major roads converge, making it a prominent landmark in the city. The monument honors those who fought and died for France during the French Revolutionary and Napoleonic Wars and is a must-visit site for its historical significance and stunning views from the top.'}
# {'User': 'What are the must-see artworks at the Louvre Museum?',
#  'Assistant': "The Louvre Museum is home to an incredible collection of artworks. Here are some must-see masterpieces you shouldn't miss during your visit:\n\n1. **Mona Lisa (La Joconde)** - Leonardo da Vinci's iconic portrait is perhaps the most famous painting in the world, known for its enigmatic smile.\n\n2. **Venus de Milo** - This ancient Greek statue of the goddess Aphrodite is celebrated for its beauty and is one of the most recognized sculptures in the museum.\n\n3. **Winged Victory of Samothrace (Nike of Samothrace)** - This stunning Hellenistic sculpture represents the goddess of victory and is admired for its dynamic form and dramatic presentation.\n\n4. **The Coronation of Napoleon** - Painted by Jacques-Louis David, this grand artwork depicts the coronation ceremony of Napoleon Bonaparte and is rich in historical detail.\n\n5. **Liberty Leading the People** - This painting by Eugène Delacroix symbolizes the July Revolution of 1830 and features the"}
